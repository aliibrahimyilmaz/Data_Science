# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings  # hem uyarı satırlarını hem de çıktı sonuçlarını bir arada görebilmenizi sağlar.
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %%
df = pd.read_json("scout_2.json")

pd.set_option('display.max_columns', None)
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat     km registration         prev_owner  hp_kW  \
# 0  15770    VAT deductible  56013      01/2016  2 previous owners   66.0
# 1  14500  Price negotiable  80000      03/2017               None  141.0
# 2  14640    VAT deductible  83450      02/2016   1 previous owner   85.0
# 3  14500              None  73000      08/2016   1 previous owner   66.0
# 4  16790              None  16200      05/2016   1 previous owner   66.0
#
#    Type   Non-smoking Vehicle  Make Model First Registration       Body Color  \
# ...

# %%
(df.isnull().sum()/df.shape[0]*100).sort_values()
# Out:
# make_model                    0.000000
# Gearing Type                  0.000000
# Model                         0.000000
# registration                  0.000000
# km                            0.000000
# Make                          0.000000
# price                         0.000000
# Fuel                          0.000000
# Type                          0.012564
# short_description             0.288963
# body_type                     0.376908
# hp_kW                         0.552799
# Nr. of Doors                  1.331742
# Displacement                  3.115774
# Body Color                    3.750236
# \nComfort & Convenience\n     5.779257
# Nr. of Seats                  6.137320
# \nSafety & Security\n         6.168729
# \nEntertainment & Media\n     8.631195
# First Registration           10.032037
# CO2 Emission                 11.357497
# Consumption                  11.973114
# \nExtras\n                   18.606696
# Emission Class               18.977323
# ...

# %% [markdown]
# #### The columns, which consist of more than approx. 40% missing values, will be dropped

# %%
df1 = df.drop(columns = ["Drive chain", "Weight", "Country version", "Non-smoking Vehicle"], axis = 1)

# %%
(df1.isnull().sum()/df1.shape[0]*100).sort_values()
# Out:
# make_model                    0.000000
# price                         0.000000
# Fuel                          0.000000
# km                            0.000000
# registration                  0.000000
# Make                          0.000000
# Model                         0.000000
# Gearing Type                  0.000000
# Type                          0.012564
# short_description             0.288963
# body_type                     0.376908
# hp_kW                         0.552799
# Nr. of Doors                  1.331742
# Displacement                  3.115774
# Body Color                    3.750236
# \nComfort & Convenience\n     5.779257
# Nr. of Seats                  6.137320
# \nSafety & Security\n         6.168729
# \nEntertainment & Media\n     8.631195
# First Registration           10.032037
# CO2 Emission                 11.357497
# Consumption                  11.973114
# \nExtras\n                   18.606696
# Emission Class               18.977323
# ...

# %% [markdown]
# #### registration

# %%
df1[["registration","First Registration"]]
# Out:
#       registration First Registration
# 0          01/2016     [\n, 2016, \n]
# 1          03/2017     [\n, 2017, \n]
# 2          02/2016     [\n, 2016, \n]
# 3          08/2016     [\n, 2016, \n]
# 4          05/2016     [\n, 2016, \n]
# ...            ...                ...
# 15914          -/-               None
# 15915      01/2019     [\n, 2019, \n]
# 15916      03/2019     [\n, 2019, \n]
# 15917      06/2019     [\n, 2019, \n]
# 15918      01/2019     [\n, 2019, \n]
#
# [15919 rows x 2 columns]

# %%
df1["First Registration"].str[1]
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914    None
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: First Registration, Length: 15919, dtype: object

# %%
df1["Registration_Year"] = df1["First Registration"].str[1] # new column from the First Registration

# %%
df1["Registration_Year"].isnull().sum()
# Out:
# 1597

# %%
df1["Registration_Year"].value_counts(dropna = False)
# Out:
# 2018    4522
# 2016    3674
# 2017    3273
# 2019    2853
# NaN     1597
# Name: Registration_Year, dtype: int64

# %%
df2 = df1.drop(columns = "First Registration", axis = 1)  # First Registration has been dropped

# %%
df2.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Body Color', 'Paint Type', 'Upholstery', 'Nr. of Doors',
#        'Nr. of Seats', 'Gearing Type', 'Displacement', 'Cylinders', 'Fuel',
#        'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'Gears', 'Registration_Year'],
#       dtype='object')

# %%
df2.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat     km registration         prev_owner  hp_kW  \
# 0  15770    VAT deductible  56013      01/2016  2 previous owners   66.0
# 1  14500  Price negotiable  80000      03/2017               None  141.0
# 2  14640    VAT deductible  83450      02/2016   1 previous owner   85.0
# 3  14500              None  73000      08/2016   1 previous owner   66.0
# 4  16790              None  16200      05/2016   1 previous owner   66.0
#
#    Type  Make Model       Body Color      Paint Type          Upholstery  \
# ...

# %% [markdown]
# #### body_color

# %%
df2["Body Color"]
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body Color, Length: 15919, dtype: object

# %%
df2["body_color"] = df2["Body Color"].str[1]

# %%
df2 = df2.drop(columns = "Body Color", axis = 1)
df2.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Paint Type', 'Upholstery', 'Nr. of Doors', 'Nr. of Seats',
#        'Gearing Type', 'Displacement', 'Cylinders', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'Gears', 'Registration_Year', 'body_color', 'paint_type'],
#       dtype='object')

# %%
df2["body_color"].value_counts(dropna = False)
# Out:
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %% [markdown]
# #### paint_type

# %%
df2["paint_type"] = df2["Paint Type"].str[0].str.strip("\n")

# %%
df2 = df2.drop(columns = "Paint Type", axis = 1)
df2.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Upholstery', 'Nr. of Doors', 'Nr. of Seats', 'Gearing Type',
#        'Displacement', 'Cylinders', 'Fuel', 'Consumption', 'CO2 Emission',
#        'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'Gears', 'Registration_Year', 'body_color', 'paint_type'],
#       dtype='object')

# %%
df2["paint_type"].value_counts(dropna = False)
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64

# %%
df2.to_json("scout_3.json")
