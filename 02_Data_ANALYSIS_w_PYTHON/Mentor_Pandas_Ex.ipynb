# %% [markdown]
# ### 6. Write a Pandas program to select the specified columns and rows from a given data frame.

# %%
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
e_data = pd.DataFrame(data = exam_data, index = labels)

# %%
e_data
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
e_data.loc[("b", "d", "f", "g"), ("score", "qualify")]
# Out:
#    score qualify
# b    9.0      no
# d    NaN      no
# f   20.0     yes
# g   14.5     yes

# %% [markdown]
# ### 8. Write a Pandas program to count the number of rows and columns of a DataFrame.

# %%
e_data.shape
# Out:
# (10, 4)

# %%
print("Number of Rows: " + str(e_data.shape[0]))
print("Number of Columns: " + str(e_data.shape[1]))
# Out:
# Number of Rows: 10
# Number of Columns: 4

# %% [markdown]
# ### 9. Write a Pandas program to select the rows where the score is missing, i.e. is NaN.

# %%
e_data[e_data.isnull()["score"]]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# ### 10. Write a Pandas program to select the rows the score is between 15 and 20 (inclusive).

# %%
e_data[(e_data["score"] <= 20) & (e_data["score"] > 15)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# ### 11. Write a Pandas program to select the rows where number of attempts in the examination is less than 2 and score greater than 15.

# %%
e_data
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
e_data[(e_data["attempts"] < 2) & (e_data["score"] > 15)]
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %% [markdown]
# ### 13. Write a Pandas program to calculate the sum of the examination attempts by the students.

# %%
e_data["attempts"].sum()
# Out:
# 19

# %% [markdown]
# ### 15. Write a Pandas program to append a new row 'k' to data frame with given values for each column. Now delete the new row and return the original DataFrame.

# %% [markdown]
# #### Values for each column will be: name : "Suresh", score: 15.5, attempts: 1, qualify: "yes", label: "k"

# %%
new_dict = {"name" : "Suresh", "score": 15.5, "attempts": 1, "qualify": "yes"}

# %%
e_data = e_data.append(new_dict, ignore_index=True)  # df.loc['k'] = ['Suresh', 15.5, 1, 'yes']

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
e_data["labels"] = labels

# %%
e_data
# Out:
#          name  score  attempts qualify labels
# 0   Anastasia   12.5         1     yes      a
# 1        Dima    9.0         3      no      b
# 2   Katherine   16.5         2     yes      c
# 3       James    NaN         3      no      d
# 4       Emily    9.0         2      no      e
# 5     Michael   20.0         3     yes      f
# 6     Matthew   14.5         1     yes      g
# 7       Laura    NaN         1      no      h
# 8       Kevin    8.0         2      no      i
# 9       Jonas   19.0         1     yes      j
# 10     Suresh   15.5         1     yes      k

# %%
e_data.set_index("labels", inplace = True)

# %%
e_data
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# d           James    NaN         3      no
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# h           Laura    NaN         1      no
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes
# k          Suresh   15.5         1     yes

# %%
e_data = e_data.drop("k")

# %%
e_data
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# d           James    NaN         3      no
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# h           Laura    NaN         1      no
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes

# %% [markdown]
# ### 16. Write a Pandas program to sort the DataFrame first by 'name' in descending order, then by 'score' in ascending order.

# %%
e_data.sort_values("name", ascending=False)
# Out:
#              name  score  attempts qualify
# labels
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# h           Laura    NaN         1      no
# i           Kevin    8.0         2      no
# c       Katherine   16.5         2     yes
# j           Jonas   19.0         1     yes
# d           James    NaN         3      no
# e           Emily    9.0         2      no
# b            Dima    9.0         3      no
# a       Anastasia   12.5         1     yes

# %%
e_data.sort_values("score")
# Out:
#              name  score  attempts qualify
# labels
# i           Kevin    8.0         2      no
# b            Dima    9.0         3      no
# e           Emily    9.0         2      no
# a       Anastasia   12.5         1     yes
# g         Matthew   14.5         1     yes
# c       Katherine   16.5         2     yes
# j           Jonas   19.0         1     yes
# f         Michael   20.0         3     yes
# d           James    NaN         3      no
# h           Laura    NaN         1      no

# %% [markdown]
# ### 17. Write a Pandas program to replace the 'qualify' column contains the values 'yes' and 'no' with True and False.

# %%
e_data
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# d           James    NaN         3      no
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# h           Laura    NaN         1      no
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes

# %%
rep = {"no" : False, "yes" : True}
e_data["qualify"] = e_data["qualify"].map(rep)

# %%
e_data
# Out:
#              name  score  attempts  qualify
# labels
# a       Anastasia   12.5         1     True
# b            Dima    9.0         3    False
# c       Katherine   16.5         2     True
# d           James    NaN         3    False
# e           Emily    9.0         2    False
# f         Michael   20.0         3     True
# g         Matthew   14.5         1     True
# h           Laura    NaN         1    False
# i           Kevin    8.0         2    False
# j           Jonas   19.0         1     True

# %% [markdown]
# ### Convert json files into Pandas.DataFrame

# %%
Json1 = [{'name': 'JOHN', 'age': 27}, {'name': 'HENRY2', 'age': 14}]
Json2 = { 1:{'name': 'vikash', 'age': 27}, 2:{'name': 'Satyam', 'age': 14} }
data = [{'id': 1, 'name': "Cole Volk", 'fitness': {'height': 130, 'weight': 60}},\
    {'id': 2,'name': "Mose Reg", 'fitness': {'height': 130, 'weight': 60}}, 
        {'id': 3, 'name': 'Faye Raker', 'fitness': {'height': 130, 'weight': 60}}]

# %%
df1 = pd.DataFrame(Json1)
df1
# Out:
#      name  age
# 0    JOHN   27
# 1  HENRY2   14

# %%
df2 = pd.DataFrame(Json2)
df2
# Out:
#            1       2
# name  vikash  Satyam
# age       27      14

# %%
df_data = pd.json_normalize(data)
df_data
# Out:
#    id        name  fitness.height  fitness.weight
# 0   1   Cole Volk             130              60
# 1   2    Mose Reg             130              60
# 2   3  Faye Raker             130              60

# %%
data = [{'id': 1,
         'name': "Cole Volk",
         'fitness': {'height': 130, 'weight': 60}},
        {'name': "Mose Reg",
          'fitness': {'height': 130, 'weight': 60}},
        {'id': 2, 'name': 'Faye Raker',
         'fitness': {'height': 130, 'weight': 60}}]
pd.json_normalize(data, max_level=1)
# Out:
#     id        name  fitness.height  fitness.weight
# 0  1.0   Cole Volk             130              60
# 1  NaN    Mose Reg             130              60
# 2  2.0  Faye Raker             130              60

# %%
pd.json_normalize(data)
# Out:
#     id        name  fitness.height  fitness.weight
# 0  1.0   Cole Volk             130              60
# 1  NaN    Mose Reg             130              60
# 2  2.0  Faye Raker             130              60
