# %% [markdown]
# # ML LAB-6

# %% [markdown]
# #### Data Sources: https://github.com/owid/covid-19-data/tree/master/public/data
# ####               https://en.wikipedia.org/wiki/World_Happiness_Report

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cnt = pd.read_csv ("countries.csv")
cnt.sample(10)
# Out:
#               location  population  population_density  median_age  \
# 52   Equatorial Guinea     1402985              45.194        22.4
# 108          Mauritius     1271767             622.962        37.4
# 55            Eswatini     1160164              79.492        21.5
# 151          Singapore     5850343            7915.731        42.4
# 107         Mauritania     4649660               4.289        20.3
# 74             Hungary     9660350             108.043        43.4
# 162           Suriname      586634               3.612        29.6
# 64               Ghana    31072945             126.719        21.1
# 141        Saint Lucia      183629             293.187        34.9
# 19              Bhutan      771612              21.188        28.6
#
#      aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 52           2.846          1.752       22604.873              NaN
# 108         10.945          5.884       20292.745              0.5
# 55           3.163          1.845        7738.975              NaN
# 151         12.922          7.049       85535.383              NaN
# 107          3.138          1.792        3597.633              6.0
# 74          18.577         11.976       26777.561              0.5
# 162          6.933          4.229       13767.119              NaN
# 64           3.385          1.948        4227.630             12.0
# 141          9.721          6.405       12951.839              NaN
# 19           4.885          2.977        8708.597              1.5
#
#      life_expectancy  human_development_index
# 52             58.74                    0.591
# 108            74.99                    0.790
# 55             60.19                    0.588
# 151            83.62                    0.932
# 107            64.92                    0.520
# 74             76.88                    0.838
# 162            71.68                    0.720
# 64             64.07                    0.592
# 141            76.20                    0.747
# 19             71.78                    0.612

# %%
cnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 190 non-null    object
#  1   population               190 non-null    int64
#  2   population_density       186 non-null    float64
#  3   median_age               181 non-null    float64
#  4   aged_65_older            179 non-null    float64
#  5   aged_70_older            180 non-null    float64
#  6   gdp_per_capita           182 non-null    float64
#  7   extreme_poverty          124 non-null    float64
#  8   life_expectancy          189 non-null    float64
#  9   human_development_index  183 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 15.0+ KB

# %%
happy_score_cnt = pd.read_csv('happiness_scores.csv')

# %%
happy_score_cnt.head()
# Out:
#       location  happiness_score
# 0      Finland            7.809
# 1      Denmark            7.646
# 2  Switzerland            7.560
# 3      Iceland            7.504
# 4       Norway            7.488

# %%
cnt = pd.merge(cnt, happy_score_cnt, on = "location", how = "left")
cnt.head()
# Out:
#       location  population  population_density  median_age  aged_65_older  \
# 0  Afghanistan    38928341              54.422        18.6          2.581
# 1      Albania     2877800             104.871        38.0         13.188
# 2      Algeria    43851043              17.348        29.1          6.211
# 3      Andorra       77265             163.755         NaN            NaN
# 4       Angola    32866268              23.890        16.8          2.405
#
#    aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# 0          1.337        1803.987              NaN            64.83
# 1          8.643       11803.431              1.1            78.57
# 2          3.857       13913.839              0.5            76.88
# 3            NaN             NaN              NaN            83.73
# 4          1.362        5819.495              NaN            61.15
#
#    human_development_index  happiness_score
# 0                    0.498            2.567
# 1                    0.785            4.883
# 2                    0.754            5.005
# 3                    0.858              NaN
# 4                    0.581              NaN

# %% [markdown]
# # EDA

# %%
cnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 190 non-null    object
#  1   population               190 non-null    int64
#  2   population_density       186 non-null    float64
#  3   median_age               181 non-null    float64
#  4   aged_65_older            179 non-null    float64
#  5   aged_70_older            180 non-null    float64
#  6   gdp_per_capita           182 non-null    float64
#  7   extreme_poverty          124 non-null    float64
#  8   life_expectancy          189 non-null    float64
#  9   human_development_index  183 non-null    float64
#  10  happiness_score          149 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 17.8+ KB

# %%
cnt.describe()
# Out:
#          population  population_density  median_age  aged_65_older  \
# count  1.900000e+02          186.000000  181.000000     179.000000
# mean   8.183077e+07          341.658210   30.204972       8.590022
# std    5.819950e+08         1612.572496    9.171031       6.198639
# min    8.090000e+02            1.980000   15.100000       1.144000
# 25%    2.367885e+06           35.972500   21.700000       3.421500
# 50%    9.493482e+06           82.464000   29.400000       6.211000
# 75%    3.076120e+07          208.157000   38.700000      14.053000
# max    7.794799e+09        19347.500000   48.200000      27.049000
#
#        aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# count     180.000000      182.000000       124.000000       189.000000
# mean        5.436161    18439.706637        13.916129        72.862011
# std         4.225454    19589.091950        20.311975         7.584835
# min         0.526000      661.240000         0.100000        53.280000
# 25%         2.033500     3924.303000         0.600000        67.270000
# 50%         3.541500    11822.138500         2.350000        74.250000
# 75%         8.651750    26069.050500        21.675000        77.970000
# max        18.493000   116935.600000        77.600000        86.750000
#
#        human_development_index  happiness_score
# count               183.000000       149.000000
# mean                  0.708869         5.472221
# std                   0.154410         1.125246
# min                   0.354000         2.567000
# 25%                   0.588500         4.677000
# 50%                   0.736000         5.515000
# 75%                   0.823000         6.258000
# max                   0.953000         7.809000

# %%
cnt[(cnt["population"] < 1000) | (cnt["population"] > 1000000000) | (cnt["population_density"] > 15000)]
# Out:
#     location  population  population_density  median_age  aged_65_older  \
# 35     China  1439323774             147.674        38.7         10.641
# 76     India  1380004385             450.419        28.2          5.989
# 111   Monaco       39244           19347.500         NaN            NaN
# 183  Vatican         809                 NaN         NaN            NaN
# 186    World  7794798729              58.045        30.9          8.696
#
#      aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# 35           5.929       15308.712              0.7            76.91
# 76           3.414        6426.674             21.2            69.66
# 111            NaN             NaN              NaN            86.75
# 183            NaN             NaN              NaN            75.12
# 186          5.355       15469.207             10.0            72.58
#
#      human_development_index  happiness_score
# 35                     0.752            5.124
# 76                     0.640            3.573
# 111                      NaN              NaN
# 183                      NaN              NaN
# 186                      NaN              NaN

# %%
cnt[(cnt["gdp_per_capita"] < 1000) | (cnt["extreme_poverty"] > 70)]
# Out:
#                          location  population  population_density  median_age  \
# 27                        Burundi    11890781             423.062        17.5
# 32       Central African Republic     4829764               7.479        18.3
# 44   Democratic Republic of Congo    89561404              35.879        17.0
# 95                        Liberia     5057677              49.127        19.2
# 100                    Madagascar    27691019              43.951        19.6
# 101                        Malawi    19129955             197.519        18.1
# 122                         Niger    24206636              16.955        15.1
#
#      aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 27           2.562          1.504         702.225             71.7
# 32           3.655          2.251         661.240              NaN
# 44           3.020          1.745         808.133             77.1
# 95           3.057          1.756         752.788             38.6
# 100          2.929          1.686        1416.440             77.6
# 101          2.979          1.783        1095.042             71.4
# 122          2.553          1.378         926.000             44.5
#
#      life_expectancy  human_development_index  happiness_score
# 27             61.58                    0.417            3.775
# 32             53.28                    0.367            3.476
# 44             60.68                    0.457            5.194
# 95             64.10                    0.435            4.558
# 100            67.04                    0.519            4.166
# 101            64.26                    0.477            3.538
# 122            62.42                    0.354            4.910

# %%
cnt.set_index("location", inplace = True)

# %%
cnt.head()
# Out:
#              population  population_density  median_age  aged_65_older  \
# location
# Afghanistan    38928341              54.422        18.6          2.581
# Albania         2877800             104.871        38.0         13.188
# Algeria        43851043              17.348        29.1          6.211
# Andorra           77265             163.755         NaN            NaN
# Angola         32866268              23.890        16.8          2.405
#
#              aged_70_older  gdp_per_capita  extreme_poverty  life_expectancy  \
# location
# Afghanistan          1.337        1803.987              NaN            64.83
# Albania              8.643       11803.431              1.1            78.57
# Algeria              3.857       13913.839              0.5            76.88
# Andorra                NaN             NaN              NaN            83.73
# Angola               1.362        5819.495              NaN            61.15
#
#              human_development_index  happiness_score
# location
# Afghanistan                    0.498            2.567
# Albania                        0.785            4.883
# Algeria                        0.754            5.005
# Andorra                        0.858              NaN
# Angola                         0.581              NaN

# %%
sns.pairplot(cnt)

# %%
cnt_new = cnt[["median_age", "aged_65_older", "gdp_per_capita", "extreme_poverty", "life_expectancy", "human_development_index", "happiness_score"]]
cnt_new.sample(10)
# Out:
#               median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# Australia           37.9         15.504       44648.710              0.5
# Israel              30.6         11.733       33132.320              0.5
# Gabon               23.1          4.450       16562.413              3.4
# Monaco               NaN            NaN             NaN              NaN
# Mexico              29.3          6.857       17336.469              2.5
# Madagascar          19.6          2.929        1416.440             77.6
# Kazakhstan          30.6          6.991       24055.588              0.1
# Sierra Leone        19.1          2.538        1390.300             52.2
# Honduras            24.9          4.652        4541.795             16.0
# Fiji                28.6          6.224        8702.975              1.4
#
#               life_expectancy  human_development_index  happiness_score
# location
# Australia               83.44                    0.939            7.223
# Israel                  82.97                    0.903            7.129
# Gabon                   66.47                    0.702            4.829
# Monaco                  86.75                      NaN              NaN
# Mexico                  75.05                    0.774            6.465
# Madagascar              67.04                    0.519            4.166
# Kazakhstan              73.60                    0.800            6.058
# Sierra Leone            54.70                    0.419            3.926
# Honduras                75.27                    0.617            5.953
# Fiji                    67.44                    0.741              NaN

# %%
cnt_new.isnull().sum()
# Out:
# median_age                  9
# aged_65_older              11
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             1
# human_development_index     7
# happiness_score            41
# dtype: int64

# %%
cnt_new.loc["World"]
# Out:
# median_age                    30.900
# aged_65_older                  8.696
# gdp_per_capita             15469.207
# extreme_poverty               10.000
# life_expectancy               72.580
# human_development_index          NaN
# happiness_score                  NaN
# Name: World, dtype: float64

# %%
for col in ["median_age", "aged_65_older", "life_expectancy"]:
    cnt_new[col].fillna(cnt_new[col]['World'], inplace=True)

cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     7
# happiness_score            41
# dtype: int64

# %%
cnt_new['human_development_index'].fillna(cnt_new['human_development_index'].mean(), inplace=True)

cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     0
# happiness_score            41
# dtype: int64

# %%
cnt_new[cnt_new["extreme_poverty"].isnull()].sample(20)
# Out:
#                                   median_age  aged_65_older  gdp_per_capita  \
# location
# Switzerland                             43.1         18.436       57410.166
# New Zealand                             37.9         15.322       36085.843
# Bahrain                                 32.4          2.372       43290.705
# Vatican                                 30.9          8.696             NaN
# Angola                                  16.8          2.405        5819.495
# Suriname                                29.6          6.933       13767.119
# Lebanon                                 31.1          8.514       13367.565
# Finland                                 42.8         21.228       40585.721
# Cambodia                                25.6          4.412        3645.070
# Somalia                                 16.8          2.731             NaN
# Antigua and Barbuda                     32.1          6.933       21490.943
# Liechtenstein                           30.9          8.696             NaN
# Singapore                               42.4         12.922       85535.383
# Cape Verde                              25.7          4.460        6222.554
# Maldives                                30.6          4.120       15183.616
# Germany                                 46.6         21.453       45229.245
# Saint Vincent and the Grenadines        31.8          7.724       10727.146
# Eswatini                                21.5          3.163        7738.975
# Saint Lucia                             34.9          9.721       12951.839
# Afghanistan                             18.6          2.581        1803.987
#
#                                   extreme_poverty  life_expectancy  \
# location
# Switzerland                                   NaN            83.78
# New Zealand                                   NaN            82.29
# Bahrain                                       NaN            77.29
# Vatican                                       NaN            75.12
# Angola                                        NaN            61.15
# Suriname                                      NaN            71.68
# Lebanon                                       NaN            78.93
# Finland                                       NaN            81.91
# Cambodia                                      NaN            69.82
# Somalia                                       NaN            57.40
# Antigua and Barbuda                           NaN            77.02
# Liechtenstein                                 NaN            82.49
# Singapore                                     NaN            83.62
# Cape Verde                                    NaN            72.98
# Maldives                                      NaN            78.92
# Germany                                       NaN            81.33
# Saint Vincent and the Grenadines              NaN            72.53
# Eswatini                                      NaN            60.19
# Saint Lucia                                   NaN            76.20
# Afghanistan                                   NaN            64.83
#
#                                   human_development_index  happiness_score
# location
# Switzerland                                      0.944000            7.560
# New Zealand                                      0.917000            7.300
# Bahrain                                          0.846000            6.227
# Vatican                                          0.708869              NaN
# Angola                                           0.581000              NaN
# Suriname                                         0.720000              NaN
# Lebanon                                          0.757000            4.772
# Finland                                          0.920000            7.809
# Cambodia                                         0.582000            4.848
# Somalia                                          0.708869              NaN
# Antigua and Barbuda                              0.780000              NaN
# Liechtenstein                                    0.916000              NaN
# Singapore                                        0.932000            6.377
# Cape Verde                                       0.654000              NaN
# Maldives                                         0.717000            5.198
# Germany                                          0.936000            7.076
# Saint Vincent and the Grenadines                 0.723000              NaN
# Eswatini                                         0.588000            4.308
# Saint Lucia                                      0.747000              NaN
# Afghanistan                                      0.498000            2.567

# %%
cnt_new.corr()["extreme_poverty"].sort_values(ascending = False)
# Out:
# extreme_poverty            1.000000
# gdp_per_capita            -0.507473
# aged_65_older             -0.573485
# happiness_score           -0.600319
# median_age                -0.697723
# life_expectancy           -0.751798
# human_development_index   -0.769612
# Name: extreme_poverty, dtype: float64

# %%
cnt_new.corr()["gdp_per_capita"].sort_values(ascending = False)
# Out:
# gdp_per_capita             1.000000
# human_development_index    0.750823
# happiness_score            0.727942
# life_expectancy            0.673646
# median_age                 0.639722
# aged_65_older              0.500403
# extreme_poverty           -0.507473
# Name: gdp_per_capita, dtype: float64

# %%
cnt_new.corr()["happiness_score"].sort_values(ascending = False)
# Out:
# happiness_score            1.000000
# human_development_index    0.787390
# life_expectancy            0.761917
# gdp_per_capita             0.727942
# median_age                 0.688966
# aged_65_older              0.641272
# extreme_poverty           -0.600319
# Name: happiness_score, dtype: float64

# %%
from sklearn.cluster import KMeans

# %%
cnt_hdi = cnt_new["human_development_index"].values.reshape(-1, 1)

# %%
# !pip install yellowbrick 
from yellowbrick.cluster import KElbowVisualizer

# %%
kmeans = KMeans()

visu = KElbowVisualizer(kmeans, k=(2, 10))
visu.fit(cnt_hdi)
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_model = KMeans(n_clusters=4).fit(cnt_hdi)

# %%
cnt_hdi_pred = kmeans_model.predict(cnt_hdi)

print(cnt_hdi_pred)
# Out:
# [0 1 1 3 2 1 3 1 3 3 1 1 3 2 1 1 3 1 0 2 1 1 1 1 3 1 0 0 2 2 3 2 0 0 3 1 1
#  0 2 1 0 3 1 3 0 3 0 1 1 1 1 2 2 0 3 2 0 1 3 3 1 0 1 3 2 3 1 2 0 0 2 0 2 3
#  3 3 2 1 1 1 3 3 3 1 3 1 1 2 1 1 2 2 3 1 0 0 1 3 3 3 0 0 1 1 0 3 1 0 1 1 1
#  1 1 1 2 0 2 2 2 3 3 2 0 0 1 3 1 2 1 1 2 1 1 1 3 3 3 1 1 0 1 1 1 1 1 2 3 0
#  1 1 0 3 3 3 2 1 1 3 0 3 1 0 1 3 3 2 1 2 2 1 2 0 1 1 1 0 1 3 3 3 1 1 2 1 1
#  1 1 0 2 2]

# %%
np.unique(cnt_hdi_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([33, 77, 34, 46], dtype=int64))

# %%
cnt_new["hdi_clusters"] = cnt_hdi_pred
cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581        1803.987
# Albania                    38.0         13.188       11803.431
# Algeria                    29.1          6.211       13913.839
# Andorra                    30.9          8.696             NaN
# Angola                     16.8          2.405        5819.495
# Antigua and Barbuda        32.1          6.933       21490.943
# Argentina                  31.9         11.198       18933.907
# Armenia                    35.7         11.232        8787.580
# Australia                  37.9         15.504       44648.710
# Austria                    44.4         19.202       45436.686
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498            2.567             0
# Albania                                0.785            4.883             1
# Algeria                                0.754            5.005             1
# Andorra                                0.858              NaN             3
# Angola                                 0.581              NaN             2
# Antigua and Barbuda                    0.780              NaN             1
# Argentina                              0.825            5.975             3
# Armenia                                0.755            4.677             1
# Australia                              0.939            7.223             3
# Austria                                0.908            7.294             3

# %%
hdi_avg_hs = cnt_new.groupby("hdi_clusters")["happiness_score"].mean()
hdi_avg_hs
# Out:
# hdi_clusters
# 0    4.206250
# 1    5.446964
# 2    4.906565
# 3    6.659643
# Name: happiness_score, dtype: float64

# %%
cnt_new["happiness_score"] = cnt_new.groupby("hdi_clusters")["happiness_score"].apply(lambda x: x.fillna(x.mean()))

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581        1803.987
# Albania                    38.0         13.188       11803.431
# Algeria                    29.1          6.211       13913.839
# Andorra                    30.9          8.696             NaN
# Angola                     16.8          2.405        5819.495
# Antigua and Barbuda        32.1          6.933       21490.943
# Argentina                  31.9         11.198       18933.907
# Armenia                    35.7         11.232        8787.580
# Australia                  37.9         15.504       44648.710
# Austria                    44.4         19.202       45436.686
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             0
# Albania                                0.785         4.883000             1
# Algeria                                0.754         5.005000             1
# Andorra                                0.858         6.659643             3
# Angola                                 0.581         4.906565             2
# Antigua and Barbuda                    0.780         5.446964             1
# Argentina                              0.825         5.975000             3
# Armenia                                0.755         4.677000             1
# Australia                              0.939         7.223000             3
# Austria                                0.908         7.294000             3

# %%
cnt_new.isnull().sum()
# Out:
# median_age                  0
# aged_65_older               0
# gdp_per_capita              8
# extreme_poverty            66
# life_expectancy             0
# human_development_index     0
# happiness_score             0
# hdi_clusters                0
# dtype: int64

# %%
cnt_new["gdp_per_capita"] = cnt_new.groupby("hdi_clusters")["gdp_per_capita"].apply(lambda x: x.fillna(x.mean()))
cnt_new["gdp_per_capita"] = cnt_new["gdp_per_capita"].fillna(cnt_new["gdp_per_capita"].mean())

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581       1803.9870
# Albania                    38.0         13.188      11803.4310
# Algeria                    29.1          6.211      13913.8390
# Andorra                    30.9          8.696      44472.9145
# Angola                     16.8          2.405       5819.4950
# Antigua and Barbuda        32.1          6.933      21490.9430
# Argentina                  31.9         11.198      18933.9070
# Armenia                    35.7         11.232       8787.5800
# Australia                  37.9         15.504      44648.7100
# Austria                    44.4         19.202      45436.6860
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                      NaN            64.83
# Albania                          1.1            78.57
# Algeria                          0.5            76.88
# Andorra                          NaN            83.73
# Angola                           NaN            61.15
# Antigua and Barbuda              NaN            77.02
# Argentina                        0.6            76.67
# Armenia                          1.8            75.09
# Australia                        0.5            83.44
# Austria                          0.7            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             0
# Albania                                0.785         4.883000             1
# Algeria                                0.754         5.005000             1
# Andorra                                0.858         6.659643             3
# Angola                                 0.581         4.906565             2
# Antigua and Barbuda                    0.780         5.446964             1
# Argentina                              0.825         5.975000             3
# Armenia                                0.755         4.677000             1
# Australia                              0.939         7.223000             3
# Austria                                0.908         7.294000             3

# %%
hdi_avg_pvrty = cnt_new.groupby("hdi_clusters")["extreme_poverty"].mean()        
hdi_avg_pvrty
# Out:
# hdi_clusters
# 0    43.400000
# 1     2.355556
# 2    18.261538
# 3     0.607407
# Name: extreme_poverty, dtype: float64

# %%
cnt_new["extreme_poverty"] = cnt_new.groupby("hdi_clusters")["extreme_poverty"].apply(lambda x: x.fillna(x.mean()))
cnt_new["extreme_poverty"] = cnt_new["extreme_poverty"].fillna(cnt_new["extreme_poverty"].mean())

cnt_new.head(10)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581       1803.9870
# Albania                    38.0         13.188      11803.4310
# Algeria                    29.1          6.211      13913.8390
# Andorra                    30.9          8.696      44472.9145
# Angola                     16.8          2.405       5819.4950
# Antigua and Barbuda        32.1          6.933      21490.9430
# Argentina                  31.9         11.198      18933.9070
# Armenia                    35.7         11.232       8787.5800
# Australia                  37.9         15.504      44648.7100
# Austria                    44.4         19.202      45436.6860
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                43.400000            64.83
# Albania                     1.100000            78.57
# Algeria                     0.500000            76.88
# Andorra                     0.607407            83.73
# Angola                     18.261538            61.15
# Antigua and Barbuda         2.355556            77.02
# Argentina                   0.600000            76.67
# Armenia                     1.800000            75.09
# Australia                   0.500000            83.44
# Austria                     0.700000            81.54
#
#                      human_development_index  happiness_score  hdi_clusters
# location
# Afghanistan                            0.498         2.567000             0
# Albania                                0.785         4.883000             1
# Algeria                                0.754         5.005000             1
# Andorra                                0.858         6.659643             3
# Angola                                 0.581         4.906565             2
# Antigua and Barbuda                    0.780         5.446964             1
# Argentina                              0.825         5.975000             3
# Armenia                                0.755         4.677000             1
# Australia                              0.939         7.223000             3
# Austria                                0.908         7.294000             3

# %%
cnt_new.isnull().sum()
# Out:
# median_age                 0
# aged_65_older              0
# gdp_per_capita             0
# extreme_poverty            0
# life_expectancy            0
# human_development_index    0
# happiness_score            0
# hdi_clusters               0
# dtype: int64

# %%
cnt_new1 = cnt_new.drop("hdi_clusters", axis=1)
cnt_new1.sample(10)
# Out:
#                        median_age  aged_65_older  gdp_per_capita  \
# location
# Mauritania                   20.3          3.138        3597.633
# Lesotho                      22.2          4.506        2851.153
# Fiji                         28.6          6.224        8702.975
# Sweden                       41.0         19.985       46949.283
# Botswana                     25.8          3.941       15807.374
# Djibouti                     25.4          4.213        2705.406
# Kenya                        20.0          2.686        2993.028
# Papua New Guinea             22.6          3.808        3823.194
# Sao Tome and Principe        18.7          2.886        3052.714
# Maldives                     30.6          4.120       15183.616
#
#                        extreme_poverty  life_expectancy  \
# location
# Mauritania                    6.000000            64.92
# Lesotho                      59.600000            54.33
# Fiji                          1.400000            67.44
# Sweden                        0.500000            82.80
# Botswana                      2.355556            69.59
# Djibouti                     22.500000            67.11
# Kenya                        36.800000            66.70
# Papua New Guinea             18.261538            64.50
# Sao Tome and Principe        32.300000            70.39
# Maldives                      2.355556            78.92
#
#                        human_development_index  happiness_score
# location
# Mauritania                               0.520         4.375000
# Lesotho                                  0.520         3.653000
# Fiji                                     0.741         5.446964
# Sweden                                   0.933         7.353000
# Botswana                                 0.717         3.479000
# Djibouti                                 0.476         4.206250
# Kenya                                    0.590         4.583000
# Papua New Guinea                         0.544         4.906565
# Sao Tome and Principe                    0.589         4.906565
# Maldives                                 0.717         5.198000

# %%
from pyclustertend import hopkins
from sklearn.preprocessing import scale

# %%
hopkins(cnt_new1, cnt_new1.shape[0])
# Out:
# 0.14993229396112384

# %%
hopkins(scale(cnt_new1), cnt_new1.shape[0])
# Out:
# 0.14544812761635934

# %%
kmeans = KMeans()

visu = KElbowVisualizer(kmeans, k=(2, 10))
visu.fit(scale(cnt_new1))
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(cnt_new1)
# Out:
# StandardScaler()

# %%
cnt_new1_scaled = scaler.transform(cnt_new1)

# %%
kmeans_model = KMeans(n_clusters=4, random_state=18).fit(cnt_new1_scaled)

# %%
cnt_new1_scaled_pred = kmeans_model.predict(cnt_new1_scaled)

print(cnt_new1_scaled_pred)
# Out:
# [1 0 0 2 3 0 0 0 2 2 0 0 0 3 0 0 2 3 1 3 3 0 3 0 2 0 1 1 3 1 2 3 1 1 0 0 0
#  3 1 0 1 2 0 2 1 2 3 0 0 0 3 0 3 1 2 3 1 3 2 2 3 3 0 2 3 2 0 3 1 1 3 1 3 2
#  2 2 3 3 0 3 2 2 2 0 2 3 0 1 0 0 3 3 2 0 1 1 0 2 2 2 1 1 0 0 1 2 0 3 0 0 0
#  0 3 0 0 1 3 3 3 2 2 0 1 1 0 2 0 3 3 0 3 0 0 3 2 2 2 2 0 1 0 0 0 3 0 3 0 1
#  0 0 1 2 2 2 3 3 3 2 1 2 0 1 0 2 2 3 0 3 1 0 3 1 0 0 0 1 0 2 2 2 0 0 3 0 0
#  0 0 1 1 1]

# %%
np.unique(cnt_new1_scaled_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3]), array([68, 35, 43, 44], dtype=int64))

# %%
from sklearn.metrics import silhouette_score
silhouette_score(cnt_new1_scaled, cnt_new1_scaled_pred)
# Out:
# 0.32029137340951414

# %%
cnt_new1['Kmeans_clusters'] = cnt_new1_scaled_pred

cnt_new1.sample(15)
# Out:
#                    median_age  aged_65_older  gdp_per_capita  extreme_poverty  \
# location
# Eswatini                 21.5          3.163        7738.975        18.261538
# Finland                  42.8         21.228       40585.721         0.607407
# China                    38.7         10.641       15308.712         0.700000
# Switzerland              43.1         18.436       57410.166         0.607407
# Bolivia                  25.4          6.704        6885.829         7.100000
# Sweden                   41.0         19.985       46949.283         0.500000
# Peru                     29.1          7.151       12236.706         3.500000
# Equatorial Guinea        22.4          2.846       22604.873        18.261538
# Lebanon                  31.1          8.514       13367.565         2.355556
# Morocco                  29.6          6.769        7485.013         1.000000
# Denmark                  42.3         19.677       46682.515         0.200000
# Grenada                  29.4          7.304       13593.877         2.355556
# Albania                  38.0         13.188       11803.431         1.100000
# Solomon Islands          20.8          3.507        2205.923        25.100000
# Malta                    42.4         19.426       36513.323         0.200000
#
#                    life_expectancy  human_development_index  happiness_score  \
# location
# Eswatini                     60.19                    0.588         4.308000
# Finland                      81.91                    0.920         7.809000
# China                        76.91                    0.752         5.124000
# Switzerland                  83.78                    0.944         7.560000
# Bolivia                      71.51                    0.693         5.747000
# Sweden                       82.80                    0.933         7.353000
# Peru                         76.74                    0.750         5.797000
# Equatorial Guinea            58.74                    0.591         4.906565
# Lebanon                      78.93                    0.757         4.772000
# Morocco                      76.68                    0.667         5.095000
# Denmark                      80.90                    0.929         7.646000
# Grenada                      72.40                    0.772         5.446964
# Albania                      78.57                    0.785         4.883000
# Solomon Islands              73.00                    0.546         4.906565
# Malta                        82.53                    0.878         6.773000
#
#                    Kmeans_clusters
# location
# Eswatini                         3
# Finland                          2
# China                            0
# Switzerland                      2
# Bolivia                          3
# Sweden                           2
# Peru                             0
# Equatorial Guinea                3
# Lebanon                          0
# Morocco                          0
# Denmark                          2
# Grenada                          0
# Albania                          0
# Solomon Islands                  3
# Malta                            2

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 2].tail(20)
# Out:
#                       median_age  aged_65_older  gdp_per_capita  \
# location
# Lithuania                   43.5         19.002       29524.265
# Luxembourg                  39.7         14.312       94277.965
# Malta                       42.4         19.426       36513.323
# Netherlands                 43.2         18.779       48472.545
# New Zealand                 37.9         15.322       36085.843
# Norway                      39.7         16.821       64800.057
# Poland                      41.8         16.763       27216.445
# Portugal                    46.2         21.502       27936.896
# Qatar                       31.9          1.307      116935.600
# Romania                     43.0         17.850       23313.199
# Singapore                   42.4         12.922       85535.383
# Slovakia                    41.2         15.070       30155.152
# Slovenia                    44.5         19.062       31400.840
# South Korea                 43.4         13.914       35938.374
# Spain                       45.5         19.436       34272.360
# Sweden                      41.0         19.985       46949.283
# Switzerland                 43.1         18.436       57410.166
# United Arab Emirates        34.0          1.144       67293.483
# United Kingdom              40.8         18.517       39753.244
# United States               38.3         15.413       54225.446
#
#                       extreme_poverty  life_expectancy  \
# location
# Lithuania                    0.700000            75.93
# Luxembourg                   0.200000            82.25
# Malta                        0.200000            82.53
# Netherlands                  0.607407            82.28
# New Zealand                  0.607407            82.29
# Norway                       0.200000            82.40
# Poland                       0.607407            78.73
# Portugal                     0.500000            82.05
# Qatar                        0.607407            80.23
# Romania                      5.700000            76.05
# Singapore                    0.607407            83.62
# Slovakia                     0.700000            77.54
# Slovenia                     0.607407            81.32
# South Korea                  0.200000            83.03
# Spain                        1.000000            83.56
# Sweden                       0.500000            82.80
# Switzerland                  0.607407            83.78
# United Arab Emirates         0.607407            77.97
# United Kingdom               0.200000            81.32
# United States                1.200000            78.86
#
#                       human_development_index  happiness_score  \
# location
# Lithuania                               0.858         6.215000
# Luxembourg                              0.904         7.238000
# Malta                                   0.878         6.773000
# Netherlands                             0.931         7.449000
# New Zealand                             0.917         7.300000
# Norway                                  0.953         7.488000
# Poland                                  0.865         6.186000
# Portugal                                0.847         5.911000
# Qatar                                   0.856         6.659643
# Romania                                 0.811         6.124000
# Singapore                               0.932         6.377000
# Slovakia                                0.855         6.281000
# Slovenia                                0.896         6.363000
# South Korea                             0.903         5.872000
# Spain                                   0.891         6.401000
# Sweden                                  0.933         7.353000
# Switzerland                             0.944         7.560000
# United Arab Emirates                    0.863         6.791000
# United Kingdom                          0.922         7.165000
# United States                           0.924         6.940000
#
#                       Kmeans_clusters
# location
# Lithuania                           2
# Luxembourg                          2
# Malta                               2
# Netherlands                         2
# New Zealand                         2
# Norway                              2
# Poland                              2
# Portugal                            2
# Qatar                               2
# Romania                             2
# Singapore                           2
# Slovakia                            2
# Slovenia                            2
# South Korea                         2
# Spain                               2
# Sweden                              2
# Switzerland                         2
# United Arab Emirates                2
# United Kingdom                      2
# United States                       2

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 0].tail(20)
# Out:
#                                   median_age  aged_65_older  gdp_per_capita  \
# location
# Saint Lucia                             34.9          9.721    12951.839000
# Saint Vincent and the Grenadines        31.8          7.724    10727.146000
# San Marino                              30.9          8.696    56861.470000
# Saudi Arabia                            31.9          3.295    49045.411000
# Serbia                                  41.2         17.366    14048.881000
# Seychelles                              36.2          8.606    26382.287000
# Sri Lanka                               34.1         10.069    11669.077000
# Suriname                                29.6          6.933    13767.119000
# Taiwan                                  42.2          8.696    16037.449722
# Thailand                                40.1         11.373    16277.671000
# Trinidad and Tobago                     36.2         10.014    28763.071000
# Tunisia                                 32.7          8.001    10849.297000
# Turkey                                  31.6          8.153    25129.341000
# Ukraine                                 41.4         16.462     7894.393000
# Uruguay                                 35.6         14.655    20551.409000
# Uzbekistan                              28.2          4.469     6253.104000
# Vatican                                 30.9          8.696    16037.449722
# Venezuela                               29.0          6.614    16745.022000
# Vietnam                                 32.6          7.150     6171.884000
# World                                   30.9          8.696    15469.207000
#
#                                   extreme_poverty  life_expectancy  \
# location
# Saint Lucia                              2.355556            76.20
# Saint Vincent and the Grenadines         2.355556            72.53
# San Marino                               2.355556            84.97
# Saudi Arabia                             0.607407            75.13
# Serbia                                   2.355556            76.00
# Seychelles                               1.100000            73.40
# Sri Lanka                                0.700000            76.98
# Suriname                                 2.355556            71.68
# Taiwan                                   2.355556            80.46
# Thailand                                 0.100000            77.15
# Trinidad and Tobago                      2.355556            73.51
# Tunisia                                  2.000000            76.70
# Turkey                                   0.200000            77.69
# Ukraine                                  0.100000            72.06
# Uruguay                                  0.100000            77.91
# Uzbekistan                               2.355556            71.72
# Vatican                                  2.355556            75.12
# Venezuela                                2.355556            72.06
# Vietnam                                  2.000000            75.40
# World                                   10.000000            72.58
#
#                                   human_development_index  happiness_score  \
# location
# Saint Lucia                                      0.747000         5.446964
# Saint Vincent and the Grenadines                 0.723000         5.446964
# San Marino                                       0.708869         5.446964
# Saudi Arabia                                     0.853000         6.406000
# Serbia                                           0.787000         5.778000
# Seychelles                                       0.797000         5.446964
# Sri Lanka                                        0.770000         4.327000
# Suriname                                         0.720000         5.446964
# Taiwan                                           0.708869         6.455000
# Thailand                                         0.755000         5.999000
# Trinidad and Tobago                              0.784000         6.192000
# Tunisia                                          0.735000         4.392000
# Turkey                                           0.791000         5.132000
# Ukraine                                          0.751000         4.561000
# Uruguay                                          0.804000         6.440000
# Uzbekistan                                       0.710000         6.258000
# Vatican                                          0.708869         5.446964
# Venezuela                                        0.761000         5.053000
# Vietnam                                          0.694000         5.353000
# World                                            0.708869         5.446964
#
#                                   Kmeans_clusters
# location
# Saint Lucia                                     0
# Saint Vincent and the Grenadines                0
# San Marino                                      0
# Saudi Arabia                                    0
# Serbia                                          0
# Seychelles                                      0
# Sri Lanka                                       0
# Suriname                                        0
# Taiwan                                          0
# Thailand                                        0
# Trinidad and Tobago                             0
# Tunisia                                         0
# Turkey                                          0
# Ukraine                                         0
# Uruguay                                         0
# Uzbekistan                                      0
# Vatican                                         0
# Venezuela                                       0
# Vietnam                                         0
# World                                           0

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
linked = linkage(cnt_new1_scaled, "ward")

# %%
plt.figure(figsize = (20,8))
plt.title("Dendogram")
plt.xlabel("Observations")
plt.ylabel("Distances")
dendrogram(linked);

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
Hr_model = AgglomerativeClustering (n_clusters = 4)
cnt_new1_scaled_pred_hr = Hr_model.fit_predict(cnt_new1_scaled)

# %%
clusters = Hr_model.labels_

# %%
np.unique(cnt_new1_scaled_pred_hr, return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int64), array([49, 37, 74, 30], dtype=int64))

# %%
silhouette_score(cnt_new1_scaled, cnt_new1_scaled_pred_hr)
# Out:
# 0.3277267844084182

# %%
cnt_new1["Hr_predicted_clusters"]=clusters

# %%
cnt_new1.sample(20)
# Out:
#                      median_age  aged_65_older  gdp_per_capita  \
# location
# Afghanistan                18.6          2.581     1803.987000
# Brazil                     33.5          8.552    14103.452000
# Suriname                   29.6          6.933    13767.119000
# Mozambique                 17.7          3.158     1136.103000
# Greece                     45.3         20.396    24574.382000
# Somalia                    16.8          2.731    16037.449722
# Mauritania                 20.3          3.138     3597.633000
# Eritrea                    19.3          3.607     1510.459000
# Djibouti                   25.4          4.213     2705.406000
# Canada                     41.4         16.984    44017.591000
# Albania                    38.0         13.188    11803.431000
# Nepal                      25.0          5.809     2442.804000
# Antigua and Barbuda        32.1          6.933    21490.943000
# Ireland                    38.7         13.928    67335.293000
# Solomon Islands            20.8          3.507     2205.923000
# Tanzania                   17.7          3.108     2683.304000
# Guinea-Bissau              19.4          3.002     1548.675000
# Venezuela                  29.0          6.614    16745.022000
# Kyrgyzstan                 26.3          4.489     3393.474000
# Uganda                     16.4          2.168     1697.707000
#
#                      extreme_poverty  life_expectancy  \
# location
# Afghanistan                43.400000            64.83
# Brazil                      3.400000            75.88
# Suriname                    2.355556            71.68
# Mozambique                 62.900000            60.85
# Greece                      1.500000            82.24
# Somalia                     2.355556            57.40
# Mauritania                  6.000000            64.92
# Eritrea                    43.400000            66.32
# Djibouti                   22.500000            67.11
# Canada                      0.500000            82.43
# Albania                     1.100000            78.57
# Nepal                      15.000000            70.78
# Antigua and Barbuda         2.355556            77.02
# Ireland                     0.200000            82.30
# Solomon Islands            25.100000            73.00
# Tanzania                   49.100000            65.46
# Guinea-Bissau              67.100000            58.32
# Venezuela                   2.355556            72.06
# Kyrgyzstan                  1.400000            71.45
# Uganda                     41.600000            63.37
#
#                      human_development_index  happiness_score  \
# location
# Afghanistan                         0.498000         2.567000
# Brazil                              0.759000         6.376000
# Suriname                            0.720000         5.446964
# Mozambique                          0.437000         4.624000
# Greece                              0.870000         5.515000
# Somalia                             0.708869         5.446964
# Mauritania                          0.520000         4.375000
# Eritrea                             0.440000         4.206250
# Djibouti                            0.476000         4.206250
# Canada                              0.926000         7.232000
# Albania                             0.785000         4.883000
# Nepal                               0.574000         5.137000
# Antigua and Barbuda                 0.780000         5.446964
# Ireland                             0.938000         7.094000
# Solomon Islands                     0.546000         4.906565
# Tanzania                            0.538000         3.476000
# Guinea-Bissau                       0.455000         4.206250
# Venezuela                           0.761000         5.053000
# Kyrgyzstan                          0.672000         5.542000
# Uganda                              0.516000         4.432000
#
#                      Kmeans_clusters  Hr_predicted_clusters
# location
# Afghanistan                        1                      3
# Brazil                             0                      2
# Suriname                           0                      2
# Mozambique                         1                      3
# Greece                             2                      0
# Somalia                            3                      1
# Mauritania                         3                      1
# Eritrea                            1                      3
# Djibouti                           3                      1
# Canada                             2                      0
# Albania                            0                      2
# Nepal                              3                      1
# Antigua and Barbuda                0                      2
# Ireland                            2                      0
# Solomon Islands                    3                      1
# Tanzania                           1                      3
# Guinea-Bissau                      1                      3
# Venezuela                          0                      2
# Kyrgyzstan                         3                      2
# Uganda                             1                      3

# %%
cnt_new1[cnt_new1['Kmeans_clusters'] == 0].index
# Out:
# Index(['Angola', 'Bangladesh', 'Belize', 'Bhutan', 'Bolivia', 'Botswana',
#        'Cambodia', 'Cape Verde', 'Comoros', 'Djibouti', 'Egypt',
#        'Equatorial Guinea', 'Eswatini', 'Fiji', 'Gabon', 'Gambia', 'Ghana',
#        'Guatemala', 'Guyana', 'Honduras', 'India', 'Indonesia', 'Iraq',
#        'Jordan', 'Kyrgyzstan', 'Laos', 'Mauritania', 'Mongolia', 'Myanmar',
#        'Namibia', 'Nepal', 'Pakistan', 'Palestine', 'Papua New Guinea',
#        'Philippines', 'Samoa', 'Sao Tome and Principe', 'Solomon Islands',
#        'Somalia', 'South Africa', 'Syria', 'Tajikistan', 'Timor', 'Vanuatu'],
#       dtype='object', name='location')

# %%
cnt_new1[cnt_new1['Hr_predicted_clusters'] == 2].index
# Out:
# Index(['Albania', 'Algeria', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Azerbaijan', 'Bahamas', 'Barbados', 'Belarus', 'Belize', 'Bolivia',
#        'Bosnia and Herzegovina', 'Brazil', 'Chile', 'China', 'Colombia',
#        'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'El Salvador', 'Fiji', 'Georgia', 'Grenada', 'Guatemala', 'Honduras',
#        'Indonesia', 'Iran', 'Jamaica', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan',
#        'Lebanon', 'Libya', 'Malaysia', 'Maldives', 'Marshall Islands',
#        'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Nicaragua', 'North Macedonia', 'Pakistan', 'Panama',
#        'Paraguay', 'Peru', 'Philippines', 'Russia', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Vincent and the Grenadines', 'Samoa', 'Serbia',
#        'Seychelles', 'Sri Lanka', 'Suriname', 'Taiwan', 'Tajikistan',
#        'Thailand', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Ukraine',
#        'Uruguay', 'Uzbekistan', 'Vatican', 'Venezuela', 'Vietnam', 'World'],
#       dtype='object', name='location')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(15,8))
ax1.set_title('Kmeans')
ax1.scatter(cnt_new1.iloc[:,0], cnt_new1.iloc[:,2], c = cnt_new1["Kmeans_clusters"], s = 50, cmap = "rainbow")
ax2.set_title("Hierarchical")
ax2.scatter(cnt_new1.iloc[:,0], cnt_new1.iloc[:,2], c = cnt_new1["Hr_predicted_clusters"], s = 50, cmap = "rainbow")

# %%
cnt_new1.to_csv("cnt.csv")
