# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings  # hem uyarı satırlarını hem de çıktı sonuçlarını bir arada görebilmenizi sağlar.
warnings.filterwarnings('ignore')
warnings.warn("this will not show")
# Out:
# In C:\Users\aliyi\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\aliyi\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\aliyi\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\aliyi\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
df = pd.read_json("scout_3.json")

pd.set_option('display.max_columns', None)
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration         prev_owner  hp_kW  Type  Make  \
# 0  VAT deductible  56013      01/2016  2 previous owners   66.0  Used  Audi
#
#   Model          Upholstery Nr. of Doors Nr. of Seats Gearing Type  \
# 0    A1  [\nCloth, Black\n]      [\n5\n]      [\n5\n]    Automatic
#
#      Displacement Cylinders    Fuel  \
# 0  [\n1,422 cc\n]   [\n3\n]  Diesel
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
#
#                CO2 Emission Emission Class  \
# 0  [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
# ...

# %% [markdown]
# #### num_door and num_seat

# %%
df["Nr. of Doors"].str[0].str.strip("\n")
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr. of Doors, Length: 15919, dtype: object

# %%
df["num_door"] = df["Nr. of Doors"].str[0].str.strip("\n")

# %%
df = df.drop("Nr. of Doors", axis = 1)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Upholstery', 'Nr. of Seats', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Fuel', 'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'Gears', 'Registration_Year', 'body_color',
#        'paint_type', 'num_door'],
#       dtype='object')

# %%
df["Nr. of Seats"].str[0].str.strip("\n")
# Out:
# 0        5
# 1        4
# 2        4
# 3        4
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    7
# 15917    7
# 15918    5
# Name: Nr. of Seats, Length: 15919, dtype: object

# %%
df["num_seat"] = df["Nr. of Seats"].str[0].str.strip("\n")

# %%
df = df.drop("Nr. of Seats", axis = 1)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Upholstery', 'Gearing Type', 'Displacement', 'Cylinders', 'Fuel',
#        'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'Gears', 'Registration_Year', 'body_color',
#        'paint_type', 'num_door', 'num_seat'],
#       dtype='object')

# %%
df = df.rename(columns = {'Registration_Year':'registration_year'})

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Upholstery', 'Gearing Type', 'Displacement', 'Cylinders', 'Fuel',
#        'Consumption', 'CO2 Emission', 'Emission Class',
#        '\nComfort & Convenience\n', '\nEntertainment & Media\n', '\nExtras\n',
#        '\nSafety & Security\n', 'Gears', 'registration_year', 'body_color',
#        'paint_type', 'num_door', 'num_seat'],
#       dtype='object')

# %% [markdown]
# #### Cylinders

# %%
df["cylinders"] = df["Cylinders"].str[0].str.strip("\n")

# %%
df.cylinders.value_counts(dropna = False)
# Out:
# 4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 2         2
# 8         2
# 1         1
# Name: cylinders, dtype: int64

# %%
df = df.drop("Cylinders", axis = 1)

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'body_type', 'price', 'vat', 'km',
#        'registration', 'prev_owner', 'hp_kW', 'Type', 'Make', 'Model',
#        'Upholstery', 'Gearing Type', 'Displacement', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'Gears', 'registration_year', 'body_color', 'paint_type', 'num_door',
#        'num_seat', 'cylinders'],
#       dtype='object')

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration         prev_owner  hp_kW  Type  Make  \
# 0  VAT deductible  56013      01/2016  2 previous owners   66.0  Used  Audi
#
#   Model          Upholstery Gearing Type    Displacement    Fuel  \
# 0    A1  [\nCloth, Black\n]    Automatic  [\n1,422 cc\n]  Diesel
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
#
#                CO2 Emission Emission Class  \
# 0  [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
#                                           \nExtras\n  \
# ...

# %% [markdown]
# #### Displacement, Emission Class

# %%
df.Displacement.str[0]
# Out:
# 0        \n1,422 cc\n
# 1        \n1,798 cc\n
# 2        \n1,598 cc\n
# 3        \n1,422 cc\n
# 4        \n1,422 cc\n
#              ...
# 15914    \n1,997 cc\n
# 15915    \n1,798 cc\n
# 15916    \n1,997 cc\n
# 15917    \n1,997 cc\n
# 15918    \n1,798 cc\n
# Name: Displacement, Length: 15919, dtype: object

# %%
df["Displacement"] = df["Displacement"].str[0].str.strip("\n")

# %%
df["Displacement"]
# Out:
# 0        1,422 cc
# 1        1,798 cc
# 2        1,598 cc
# 3        1,422 cc
# 4        1,422 cc
#            ...
# 15914    1,997 cc
# 15915    1,798 cc
# 15916    1,997 cc
# 15917    1,997 cc
# 15918    1,798 cc
# Name: Displacement, Length: 15919, dtype: object

# %%
df = df.rename(columns = {"Displacement" : "displacement_cc"})

# %%
df["displacement_cc"] = df["displacement_cc"].str.strip(" cc")

# %%
df["displacement_cc"] = df["displacement_cc"].str.replace(",", "")

# %%
df["displacement_cc"].value_counts(dropna = False)
# Out:
# 1598    4761
# 999     2438
# 1398    1314
# 1399     749
# 1229     677
#         ...
# 1195       1
# 1800       1
# 1686       1
# 1584       1
# 890        1
# Name: displacement_cc, Length: 78, dtype: int64

# %%
df["Emission Class"] = df["Emission Class"].str[0].str.strip("\n")

# %%
df = df.rename(columns = {"Emission Class" : "emission_class", "Type":"type", "Make" : "make", "Model":"model"})

# %%
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat     km registration         prev_owner  hp_kW  \
# 0  15770    VAT deductible  56013      01/2016  2 previous owners   66.0
# 1  14500  Price negotiable  80000      03/2017               None  141.0
# 2  14640    VAT deductible  83450      02/2016   1 previous owner   85.0
# 3  14500              None  73000      08/2016   1 previous owner   66.0
# 4  16790              None  16200      05/2016   1 previous owner   66.0
#
#    type  make model          Upholstery Gearing Type displacement_cc     Fuel  \
# ...

# %%
df.Gears = df.Gears.str[0].str.strip("\n")

# %%
df = df.rename(columns = {"Gears" : "gears", "Gearing Type": "gear_type", "Fuel" : "fuel"})

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration         prev_owner  hp_kW  type  make  \
# 0  VAT deductible  56013      01/2016  2 previous owners   66.0  Used  Audi
#
#   model          Upholstery  gear_type displacement_cc    fuel  \
# 0    A1  [\nCloth, Black\n]  Automatic            1422  Diesel
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
#
#                CO2 Emission emission_class  \
# 0  [\n99 g CO2/km (comb)\n]         Euro 6
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
#                                           \nExtras\n  \
# ...

# %%
df.Upholstery.value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# NaN                          3720
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# ...

# %%
df.Upholstery = df.Upholstery.str[0].str.strip("\n")

# %%
df.Upholstery.value_counts(dropna = False)
# Out:
# Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Full leather, Beige      36
# Velour, Black            36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Cloth, Blue              12
# Brown                    12
# Velour, Grey              8
# Cloth, White              8
# alcantara, Grey           6
# Cloth, Red                5
# ...

# %%
df.Upholstery.str.split(pat = ",")
# Out:
# 0               [Cloth,  Black]
# 1                [Cloth,  Grey]
# 2               [Cloth,  Black]
# 3                          None
# 4               [Cloth,  Black]
#                   ...
# 15914                      None
# 15915                   [Cloth]
# 15916    [Full leather,  Black]
# 15917            [Part leather]
# 15918    [Full leather,  Brown]
# Name: Upholstery, Length: 15919, dtype: object

# %%
df.Upholstery.str.split(",").str[0].unique() # type olanlari extract edelim
# Out:
# array(['Cloth', None, 'Part leather', 'Full leather', 'Black', 'Other',
#        'alcantara', 'Velour', 'Grey', 'Blue', 'White', 'Beige', 'Brown'],
#       dtype=object)

# %%
up_seri = df.Upholstery.str.split(",").str[0]

# %%
up_type = ['Cloth', 'Part leather', 'Full leather', 'alcantara', 'Velour', 'Other']

# %%
upholstery_type = [np.nan if item not in up_type else item for item in up_seri]

# %%
df2= pd.DataFrame(upholstery_type)
df2.head(10)
# Out:
#               0
# 0         Cloth
# 1         Cloth
# 2         Cloth
# 3           NaN
# 4         Cloth
# 5  Part leather
# 6  Part leather
# 7         Cloth
# 8         Cloth
# 9           NaN

# %%
df["upholstery_type"] = df2

# %%
df.head(50)
# Out:
#    make_model                                  short_description  \
# 0     Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1     Audi A1                                     1.8 TFSI sport
# 2     Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3     Audi A1                            1.4 TDi Design S tronic
# 4     Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# 5     Audi A1        1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# 6     Audi A1      Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# 7     Audi A1                 Sportback 1.4 TDI admired S tronic
# 8     Audi A1             SPB 1.6 TDI S-tronic Metal plus + Xeno
# 9     Audi A1              SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# 10    Audi A1        SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# 11    Audi A1  Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|...
# 12    Audi A1       Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# ...

# %%
up_color1 = ['Black', 'Grey', 'Blue', 'White', 'Beige', 'Brown']

# %%
up_seri.unique()
# Out:
# array(['Cloth', None, 'Part leather', 'Full leather', 'Black', 'Other',
#        'alcantara', 'Velour', 'Grey', 'Blue', 'White', 'Beige', 'Brown'],
#       dtype=object)

# %%
upholstery_color1 = [np.nan if item not in up_color1 else item for item in up_seri]  # ilk type ta yer alan renkler ikincisinde kullanilabilir

# %%
pd.DataFrame(upholstery_color1).value_counts().sum()  # 783 degeri color sütununa tasimaliyiz
# Out:
# 783

# %%
df.Upholstery.str.split(",").str[1].unique()
# Out:
# array([' Black', ' Grey', None, ' Other', ' White', nan, ' Red', ' Blue',
#        ' Orange', ' Brown', ' Beige', ' Yellow'], dtype=object)

# %%
up_seri2 = df.Upholstery.str.split(",").str[1].str.strip(" ")

# %%
up_seri2.unique()
# Out:
# array(['Black', 'Grey', None, 'Other', 'White', nan, 'Red', 'Blue',
#        'Orange', 'Brown', 'Beige', 'Yellow'], dtype=object)

# %%
up_color2 = ['Black', 'Grey', 'Other', 'White', 'Red', 'Blue', 'Orange', 'Brown', 'Beige', 'Yellow']

# %%
upholstery_color2 = [np.nan if item not in up_color2 else item for item in up_seri2]

# %%
df["upholstery_color"] = pd.DataFrame(upholstery_color2)

# %%
df["upholstery_color"].value_counts(dropna = False)
# Out:
# Black     7710
# NaN       5861
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery_color, dtype: int64

# %%
nafill_color = pd.DataFrame(data= upholstery_color1, columns = {"upholstery_color1"})  # type altinda yer alan renkleri color altina join ediyoruz,
                                                            # bakalim 5861 Nan degeri ne olacak, diger taraftan 783 gelecek mi?

# %%
nafill_color
# Out:
#       upholstery_color1
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 15914               NaN
# 15915               NaN
# 15916               NaN
# 15917               NaN
# 15918               NaN
#
# [15919 rows x 1 columns]

# %%
df["upholstery_color"].fillna(nafill_color.upholstery_color1).value_counts(dropna = False)  # 783 deger NAn lara yan sütundan gelmis oldu
# Out:
# Black     8201
# NaN       5078
# Grey      1376
# Other      960
# Brown      207
# Beige       54
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery_color, dtype: int64

# %%
df["upholstery_color"] = df["upholstery_color"].fillna(nafill_color.upholstery_color1)

# %%
df.head(30)
# Out:
#    make_model                                  short_description  \
# 0     Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1     Audi A1                                     1.8 TFSI sport
# 2     Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3     Audi A1                            1.4 TDi Design S tronic
# 4     Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# 5     Audi A1        1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# 6     Audi A1      Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# 7     Audi A1                 Sportback 1.4 TDI admired S tronic
# 8     Audi A1             SPB 1.6 TDI S-tronic Metal plus + Xeno
# 9     Audi A1              SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# 10    Audi A1        SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# 11    Audi A1  Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|...
# 12    Audi A1       Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# ...

# %%
# Upholstery düsürülebilir
df = df.drop(columns = "Upholstery", axis = 1)

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration         prev_owner  hp_kW  type  make  \
# 0  VAT deductible  56013      01/2016  2 previous owners   66.0  Used  Audi
#
#   model  gear_type displacement_cc    fuel  \
# 0    A1  Automatic            1422  Diesel
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
#
#                CO2 Emission emission_class  \
# 0  [\n99 g CO2/km (comb)\n]         Euro 6
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
#
# ...

# %% [markdown]
# #### prev_owner

# %%
df.prev_owner.value_counts(dropna = False)
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df.prev_owner = df.prev_owner.str[0]

# %%
df.prev_owner.value_counts(dropna = False)
# Out:
# 1      8294
# NaN    6828
# 2       778
# 3        17
# 4         2
# Name: prev_owner, dtype: int64

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration prev_owner  hp_kW  type  make model  \
# 0  VAT deductible  56013      01/2016          2   66.0  Used  Audi    A1
#
#    gear_type displacement_cc    fuel  \
# 0  Automatic            1422  Diesel
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
#
#                CO2 Emission emission_class  \
# 0  [\n99 g CO2/km (comb)\n]         Euro 6
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
#
# ...

# %% [markdown]
# #### vat

# %%
df.vat.value_counts(dropna = False)  # simdilik böyle kalabilir
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %% [markdown]
# #### short_description

# %%
df.short_description.value_counts(dropna = False).sample(55)  # simdilik böyle kalabilir
# Out:
# dCi 160cv EDC Energy Initiale Paris 7Posti + DVD      1
# Sportback 1.4 TDI S-TR 5JG+XEN+NAVI+MEDIA+DAB         1
# Sportback 1.6 TDI Ambition clean diesel Sportba       1
# intense Sportback (8VF)                               1
# 1.4 Innovation Automaat | 1e Eigenaar | IntelliLin    1
# E Color Edition ecoFlex*PDC*SHZ*LRHZ*                 1
# 1.4 *120 Jahre*5 Türer*Automatik+Bluetooth            1
# IV BUSINESS dCi 75 Energy                             3
# GS 1,6 CDTI BlueInjection Innovation St./St.          4
# Sportback 1.6TDI CD Attracted                         2
# Sportback 25 TFSI 70(95) kW(PS) 5-Gang Navi Br        1
# Turbo diesel ! ( exclusief !!!!! ) geen e-mail !      1
# A Country Tourer 2.0 CDTI ecoFlex                     1
# ST 1,6 CDTI Ecotec Edition Aut.                       2
# 1.2i Enjoy - 1er P. - Clima - Garantie - ShowRoom     1
# 1.4 Sports Tourer Sport OPC Lenk+Bose                 1
# GS 1.6D EU6 Aut. Innovation+Kamera+AGR+               1
# ...

# %% [markdown]
# #### emission_class

# %%
df.emission_class.value_counts(dropna = False)  # es bleibt so.
# Out:
# Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64

# %% [markdown]
# #### CO2 Emission

# %%
df["CO2 Emission"].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# NaN                            1808
# [\n120 g CO2/km (comb)\n]       740
# [[], [], []]                    628
# [\n99 g CO2/km (comb)\n]        545
# [\n97 g CO2/km (comb)\n]        537
#                                ...
# [\n193 g CO2/km (comb)\n]         1
# [\n171 g CO2/km (comb)\n]         1
# [\n990 g CO2/km (comb)\n]         1
# [\n1,060 g CO2/km (comb)\n]       1
# [\n183 g CO2/km (comb)\n]         1
# ...

# %%
df["CO2 Emission"].str[0]
# Out:
# 0         \n99 g CO2/km (comb)\n
# 1        \n129 g CO2/km (comb)\n
# 2         \n99 g CO2/km (comb)\n
# 3         \n99 g CO2/km (comb)\n
# 4        \n109 g CO2/km (comb)\n
#                   ...
# 15914    \n139 g CO2/km (comb)\n
# 15915    \n168 g CO2/km (comb)\n
# 15916    \n139 g CO2/km (comb)\n
# 15917    \n139 g CO2/km (comb)\n
# 15918    \n153 g CO2/km (comb)\n
# Name: CO2 Emission, Length: 15919, dtype: object

# %%
df["co2_emission"] = df["CO2 Emission"].str[0].str.extract("(\d\d\d|\d\d)")

# %%
df["co2_emission"].isnull().sum()
# Out:
# 2442

# %%
df["co2_emission"].value_counts(dropna = False)
# Out:
# NaN    2442
# 120     740
# 99      545
# 97      537
# 104     501
#        ...
# 184       1
# 177       1
# 13        1
# 183       1
# 160       1
# Name: co2_emission, Length: 118, dtype: int64

# %%
df = df.drop(axis = 1, columns = "CO2 Emission")

# %%
df.head(1)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
#
#               vat     km registration prev_owner  hp_kW  type  make model  \
# 0  VAT deductible  56013      01/2016          2   66.0  Used  Audi    A1
#
#    gear_type displacement_cc    fuel  \
# 0  Automatic            1422  Diesel
#
#                                          Consumption emission_class  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...         Euro 6
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
#
#                                \nSafety & Security\n gears  registration_year  \
# ...

# %%
df.shape
# Out:
# (15919, 31)

# %%
df.to_json("scout_5.json")
